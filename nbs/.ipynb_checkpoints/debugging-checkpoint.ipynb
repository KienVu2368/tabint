# %%
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd 
from os import path

# %%
import tabint as tb
from tabint.pre_processing import *
from tabint.dataset import *
from tabint.learner import *
from tabint.feature import *
from tabint.interpretation import *
from tabint.debug import *

# %%
file_path = '/media/zero/dropbox/Dropbox/Data science project/kaggle/home_credit_default_risk/data/'

# %%
app_train = pd.read_csv(file_path + 'application_train.csv')

# %%
app_train_proc, y, pp_outp = tabular_proc(app_train, 'TARGET', [fill_na(), app_cat(), dummies()])

# %%
cons = pp_outp['cons']; cats = pp_outp['cats']

# %%
impt_ft = [['EXT_SOURCE_3'], ['EXT_SOURCE_2'], ['AMT_GOODS_PRICE', 'AMT_CREDIT', 'AMT_ANNUITY'], ['EXT_SOURCE_1'], ['DAYS_BIRTH'], ['DAYS_EMPLOYED'], ['DAYS_ID_PUBLISH'], ['CODE_GENDER_F'], ['NAME_EDUCATION_TYPE_Higher education'], ['FLAG_OWN_CAR_N', 'OWN_CAR_AGE'], ['EXT_SOURCE_1_na'], ['CODE_GENDER_M'], ['NAME_FAMILY_STATUS_Married'],  ['DAYS_LAST_PHONE_CHANGE'], ['NAME_CONTRACT_TYPE_Cash loans'], ['AMT_REQ_CREDIT_BUREAU_HOUR_na', 'AMT_REQ_CREDIT_BUREAU_DAY_na', 'AMT_REQ_CREDIT_BUREAU_WEEK_na', 'AMT_REQ_CREDIT_BUREAU_MON_na', 'AMT_REQ_CREDIT_BUREAU_QRT_na', 'AMT_REQ_CREDIT_BUREAU_YEAR_na'], ['OCCUPATION_TYPE'], ['NAME_EDUCATION_TYPE_Secondary / secondary special'], ['REG_CITY_NOT_LIVE_CITY'], ['ORGANIZATION_TYPE'], ['DAYS_REGISTRATION'], ['NAME_INCOME_TYPE_Working'], ['FLAG_DOCUMENT_13'], ['FLAG_WORK_PHONE'], ['FLAG_DOCUMENT_16'], ['OWN_CAR_AGE_na']]

# %%
cons = [i for i in cons if i in flat_list(impt_ft)]
cats = [i for i in cats if i in flat_list(impt_ft)]

# %%
app_train_proc = app_train_proc[flat_list(impt_ft)]

# %%
ds = TBDataset.from_TBSplit(app_train_proc, y, cons, cats)

# %%
tfs = {'drop 1': ['AMT_REQ_CREDIT_BUREAU_HOUR_na', 'AMT_REQ_CREDIT_BUREAU_DAY_na',
                  'AMT_REQ_CREDIT_BUREAU_WEEK_na', 'AMT_REQ_CREDIT_BUREAU_MON_na',
                  'AMT_REQ_CREDIT_BUREAU_QRT_na', 'AMT_REQ_CREDIT_BUREAU_YEAR_na'],
    
        'apply':{'DAYS_BIRTH': lambda df: -df['DAYS_BIRTH']/365,
                 'DAYS_EMPLOYED': lambda df: -df['DAYS_EMPLOYED']/365,
                 'NEW_EXT_SOURCES_MEAN': lambda df: df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1, skipna=True),
                 'NEW_EXT_SOURCES_GEO': lambda df: (df['EXT_SOURCE_1']*df['EXT_SOURCE_2']*df['EXT_SOURCE_3'])**(1/3),
                 'AMT_CREDIT/AMT_GOODS_PRICE': lambda df: df['AMT_CREDIT']/df['AMT_GOODS_PRICE'],
                 'AMT_CREDIT/AMT_CREDIT': lambda df: df['AMT_CREDIT']/df['AMT_CREDIT'],
                 'DAYS_EMPLOYED/DAYS_BIRTH': lambda df: df['DAYS_EMPLOYED']/df['DAYS_BIRTH'],
                 'DAYS_BIRTH*EXT_SOURCE_1_na': lambda df: df['DAYS_BIRTH']*df['EXT_SOURCE_1_na']},
    
        'drop 2': ['AMT_ANNUITY', 'AMT_CREDIT', 'AMT_GOODS_PRICE']}

# %%
ds.transform(tfs)

# %%
learner = LGBLearner()

# %%
#fit again
params = {
    'task': 'train',
    'objective': 'binary',
    'n_estimators':2000,
    'learning_rate':0.03,
    'num_leaves':20,
    'colsample_bytree':.8,
    'subsample':.9,
    'max_depth':7,
    'reg_alpha':.2,
    'reg_lambda':.2,
    'min_split_gain':.01,
    'min_child_weight':2,
    'verbose':-1,
    #'is_unbalance': 'true',
    'metric':'binary_logloss'}
learner.fit(params, *ds.trn, *ds.val)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.252813	valid_1's binary_logloss: 0.303676
# Early stopping, best iteration is:
# [90]	training's binary_logloss: 0.256092	valid_1's binary_logloss: 0.30304

# %% [markdown]
# # kde

# %%
kde = KernelDensityEstimation.from_series(ds.y_trn, 'prob', learner.predict(ds.x_trn))

# %%
kde.plot()

# %%
rocauc = ReceiverOperatingCharacteristic.from_learner(learner, ds.y_val, ds.x_val)

# %%
rocauc.plot()

# %%
fpr, tpr, threshold = metrics.roc_curve(ds.y_val, learner.predict(ds.x_val))

# %%
tpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.9292282 , 0.92950683,
#        1.        ])

# %%
fpr
# Out:
# array([0.00000000e+00, 1.26869743e-05, 3.17174357e-04, ...,
#        9.28635770e-01, 9.28826074e-01, 1.00000000e+00])

# %%
threshold
# Out:
# array([1.4986138 , 0.4986138 , 0.45916563, ..., 0.05207381, 0.05205524,
#        0.05196906])

# %%
class ReceiverOperatingCharacteristic:
    def __init__(self, fpr, tpr, roc_auc):
        self.fpr, self.tpr, self.roc_auc = fpr, tpr, roc_auc
        
    @classmethod
    def from_learner(cls, learner, y, x):
        fpr, tpr, threshold = metrics.roc_curve(y, learner.predict(x))
        result = pd.DataFrame.from_dict({'thresol'})
        roc_auc = metrics.auc(fpr, tpr)
        return cls(fpr, tpr, roc_auc)
        
    def plot(self): roc_curve_plot(self.fpr, self.tpr, self.roc_auc)

# %%
rocauc.fpr
# Out:
# array([0.00000000e+00, 1.26869743e-05, 3.17174357e-04, ...,
#        9.28635770e-01, 9.28826074e-01, 1.00000000e+00])

# %% [markdown]
# # bias and varience

# %%
from sklearn.metrics import roc_auc_score

# %%
trn_score = roc_auc_score(ds.y_trn, learner.predict(ds.x_trn))

# %%
expect_err = 15

# %%
print('bias = ', 100 - trn_score*100 - expect_err)
# Out:
# bias =  10.633025780645127

# %%
val_score = roc_auc_score(ds.y_val, learner.predict(ds.x_val))

# %%
print('variance = ', trn_score*100 - val_score*100)
# Out:
# variance =  24.510335314200276

# %% [markdown]
# # with hight error

# %%
predict_result = ds.x_val

# %%
predict_result['actual'] = ds.y_val

# %%
predict_result['pred'] = learner.predict(ds.x_val)

# %%
predict_result['err'] = np.abs(predict_result.actual - predict_result.pred)

# %%
predict_result = predict_result.sort_values(by='err', ascending=False)

# %%
predict_result.head()
# Out:
#        EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  DAYS_BIRTH  DAYS_EMPLOYED  \
# 22524      0.638044      0.718080      0.910213   62.671233   -1000.665753
# 36032      0.812823      0.547069      0.677309   39.972603       2.986301
# 22484      0.771362      0.744952      0.537700   61.564384   -1000.665753
# 6774       0.744932      0.565252      0.671373   42.660274       0.350685
# 45280      0.835777      0.643825      0.505998   52.854795       8.191781
#
#        DAYS_ID_PUBLISH  CODE_GENDER_F  NAME_EDUCATION_TYPE_Higher education  \
# 22524            -4144              0                                     1
# 36032            -3886              1                                     0
# 22484            -4058              0                                     0
# 6774             -2753              1                                     0
# 45280            -2807              0                                     0
#
#        FLAG_OWN_CAR_N  OWN_CAR_AGE    ...     OWN_CAR_AGE_na  \
# 22524               1          9.0    ...               True
# 36032               1          9.0    ...               True
# 22484               1          9.0    ...               True
# 6774                0         14.0    ...              False
# 45280               1          9.0    ...               True
#
#        NEW_EXT_SOURCES_MEAN  NEW_EXT_SOURCES_GEO  AMT_CREDIT/AMT_GOODS_PRICE  \
# 22524              0.755445             0.747117                       1.000
# 36032              0.679067             0.670309                       1.000
# 22484              0.684671             0.676045                       1.000
# 6774               0.660519             0.656308                       1.000
# 45280              0.661867             0.648140                       1.132
#
#        AMT_CREDIT/AMT_CREDIT  DAYS_EMPLOYED/DAYS_BIRTH  \
# 22524                    1.0                -15.966907
# 36032                    1.0                  0.074709
# 22484                    1.0                -16.253972
# 6774                     1.0                  0.008220
# 45280                    1.0                  0.154987
#
#        DAYS_BIRTH*EXT_SOURCE_1_na  actual      pred       err
# 22524                    0.000000       1  0.051969  0.948031
# 36032                    0.000000       1  0.051969  0.948031
# 22484                    0.000000       1  0.051969  0.948031
# 6774                     0.000000       1  0.051969  0.948031
# 45280                   52.854795       1  0.051969  0.948031
#
# [5 rows x 34 columns]

# %% [markdown]
# # shape

# %%
Shap = SHAP.from_Tree(learner, ds)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...

# %%
predict_result.iloc[[0], :-3]
# Out:
#        EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  DAYS_BIRTH  DAYS_EMPLOYED  \
# 22524      0.638044       0.71808      0.910213   62.671233   -1000.665753
#
#        DAYS_ID_PUBLISH  CODE_GENDER_F  NAME_EDUCATION_TYPE_Higher education  \
# 22524            -4144              0                                     1
#
#        FLAG_OWN_CAR_N  OWN_CAR_AGE             ...              \
# 22524               1          9.0             ...
#
#        FLAG_DOCUMENT_13  FLAG_WORK_PHONE  FLAG_DOCUMENT_16  OWN_CAR_AGE_na  \
# 22524                 0                0                 0            True
#
#        NEW_EXT_SOURCES_MEAN  NEW_EXT_SOURCES_GEO  AMT_CREDIT/AMT_GOODS_PRICE  \
# 22524              0.755445             0.747117                         1.0
#
#        AMT_CREDIT/AMT_CREDIT  DAYS_EMPLOYED/DAYS_BIRTH  \
# 22524                    1.0                -15.966907
#
#        DAYS_BIRTH*EXT_SOURCE_1_na
# 22524                         0.0
#
# [1 rows x 31 columns]

# %%
Shap.force_plot_one(record = predict_result.iloc[[0], :-3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-13aa6b4877c8> in <module>()
# ----> 1 Shap.force_plot_one(record = predict_result.iloc[[0], :-3])
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/tabint/interpretation.py in force_plot_one(self, loc, record, link, plot_cmap)
#     141         result = pd.DataFrame({'Column name': self.features, 'Column value': col_value, 'Shap value': s_values})
#     142         self.shap_value_one = ResultDF(result, 'Shap value')
# --> 143         return shap.force_plot(self.explainer.expected_value, values, features = self.features, plot_cmap = plot_cmap, link = link)
#     144
#     145     def force_plot_many(self, loc, sample = 10000, plot_cmap = ["#00cc00", "#002266"]):
#
# NameError: name 'values' is not defined

# %% [markdown]
# # high error

# %%
keya = predict_result[ds.cats].iloc[[0]].values
predict_result_fil = predict_result[(predict_result[ds.cats].values == keya).all(axis=1)]

# %%
predict_result_fil[ds.cons].sample(20).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col0 {
#             background-color:  #96b6d7;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col2 {
#             background-color:  #045a8d;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col3 {
#             background-color:  #f8f1f8;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col6 {
#             background-color:  #023858;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col7 {
#             background-color:  #056fae;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col8 {
#             background-color:  #1077b4;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col9 {
#             background-color:  #4897c4;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col10 {
#             background-color:  #045585;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col11 {
#             background-color:  #3d93c2;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col12 {
#             background-color:  #056dab;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col13 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col14 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col15 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row0_col16 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col0 {
#             background-color:  #d0d1e6;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col1 {
#             background-color:  #023c5f;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col2 {
#             background-color:  #0569a5;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col3 {
#             background-color:  #eae6f1;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col5 {
#             background-color:  #a9bfdc;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col6 {
#             background-color:  #167bb6;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col7 {
#             background-color:  #bfc9e1;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col8 {
#             background-color:  #046097;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col9 {
#             background-color:  #04629a;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col10 {
#             background-color:  #1b7eb7;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col11 {
#             background-color:  #509ac6;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col12 {
#             background-color:  #1278b4;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col13 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col14 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col15 {
#             background-color:  #023b5d;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row1_col16 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col0 {
#             background-color:  #034369;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col2 {
#             background-color:  #03456c;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col3 {
#             background-color:  #034165;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col6 {
#             background-color:  #023858;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col7 {
#             background-color:  #1e80b8;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col8 {
#             background-color:  #6ba5cd;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col9 {
#             background-color:  #e9e5f1;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col10 {
#             background-color:  #034e7b;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col11 {
#             background-color:  #f1ebf5;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col12 {
#             background-color:  #a2bcda;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col13 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col14 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col15 {
#             background-color:  #b7c5df;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row2_col16 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col0 {
#             background-color:  #dddbec;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col1 {
#             background-color:  #023b5d;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col2 {
#             background-color:  #04639b;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col3 {
#             background-color:  #f2ecf5;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col4 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col5 {
#             background-color:  #023858;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col6 {
#             background-color:  #04649e;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col7 {
#             background-color:  #0569a4;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col8 {
#             background-color:  #045280;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col9 {
#             background-color:  #4897c4;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col10 {
#             background-color:  #045e94;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col11 {
#             background-color:  #056ba9;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col12 {
#             background-color:  #045b8e;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col13 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col14 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col15 {
#             background-color:  #02395a;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row3_col16 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col0 {
#             background-color:  #86b0d3;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col1 {
#             background-color:  #023c5f;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col2 {
#             background-color:  #4496c3;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col3 {
#             background-color:  #c2cbe2;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col4 {
#             background-color:  #fff7fb;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col5 {
#             background-color:  #a9bfdc;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col6 {
#             background-color:  #e7e3f0;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d630row4_col7 {
#             background-color:  #046097;
#         }    #T_e40d58a2_caea_11e8_861e_8c705a65d63

# %% [markdown]
# # kde plot

# %%
kde = KernelDensityEstimation.from_df(predict_result_fil, 'actual', ds.cons)

# %%
kde.plot()

# %%
def choose_df(df):
    return df[0:1]
    #if df.shape[0] == 1: return df, df
    #else: , df[1:2]

# %%
predict_result[1:3]
# Out:
#        EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  DAYS_BIRTH  DAYS_EMPLOYED  \
# 36032      0.812823      0.547069      0.677309   39.972603       2.986301
# 22484      0.771362      0.744952      0.537700   61.564384   -1000.665753
#
#        DAYS_ID_PUBLISH  CODE_GENDER_F  NAME_EDUCATION_TYPE_Higher education  \
# 36032            -3886              1                                     0
# 22484            -4058              0                                     0
#
#        FLAG_OWN_CAR_N  OWN_CAR_AGE    ...     OWN_CAR_AGE_na  \
# 36032               1          9.0    ...               True
# 22484               1          9.0    ...               True
#
#        NEW_EXT_SOURCES_MEAN  NEW_EXT_SOURCES_GEO  AMT_CREDIT/AMT_GOODS_PRICE  \
# 36032              0.679067             0.670309                         1.0
# 22484              0.684671             0.676045                         1.0
#
#        AMT_CREDIT/AMT_CREDIT  DAYS_EMPLOYED/DAYS_BIRTH  \
# 36032                    1.0                  0.074709
# 22484                    1.0                -16.253972
#
#        DAYS_BIRTH*EXT_SOURCE_1_na  actual      pred       err
# 36032                         0.0       1  0.051969  0.948031
# 22484                         0.0       1  0.051969  0.948031
#
# [2 rows x 34 columns]

# %%
a = predict_result.groupby(ds.cats).apply(choose_df)

# %%
import random
