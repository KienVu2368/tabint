# %% [markdown]
# # a

# %%
import sys
sys.path.insert(1, 'D:\\Project\\tabint')

# %%
import tabint
from tabint.utils import *
from tabint.dataset import *
from tabint.feature import *
from tabint.pre_processing import *
from tabint.visual import *
from tabint.learner import *
from tabint.interpretation import *
from tabint.inference import *

# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

# %%
df2
# Out:
# arrival_date_month   April   August  December  February  January     July  \
# hotel
# City Hotel          741414  1174523    350258    262228   211502  1242233
# Resort Hotel        310077   506505    148488    123903    57141   483747
#
# arrival_date_month    June   March     May  November  October  September
# hotel
# City Hotel          981595  472485  956348    409656   957114     945979
# Resort Hotel        421302  214263  430818    110634   415506     490204

# %%
pd.crosstab
# Out:
# <function pandas.core.reshape.pivot.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name='All', dropna=True, normalize=False)>

# %%
def crosstab(df, row, column, cmap=cm, **kagrs):
    df_crosstab = pd.crosstab(df[row], df[column], **kagrs)
    return df_crosstab.style.apply(background_gradient, m=df_crosstab.min().min(), M=df_crosstab.max().max(), cmap=cm)

# %%
crosstab(df, "hotel",  "arrival_date_month")
# Out:
# <style  type="text/css" >
#     #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col0 {
#             background-color:  #329c32;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col1 {
#             background-color:  #008000;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col2 {
#             background-color:  #a4dba4;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col3 {
#             background-color:  #88cb88;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col4 {
#             background-color:  #b1e2b1;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col5 {
#             background-color:  #1e901e;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col6 {
#             background-color:  #259425;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col7 {
#             background-color:  #56af56;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col8 {
#             background-color:  #198e19;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col9 {
#             background-color:  #9dd79d;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col10 {
#             background-color:  #2e992e;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col11 {
#             background-color:  #359d35;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col0 {
#             background-color:  #b6e5b6;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col1 {
#             background-color:  #8bcd8b;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col2 {
#             background-color:  #d6f7d6;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col3 {
#             background-color:  #c7eec7;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col5 {
#             background-color:  #95d395;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col6 {
#             background-color:  #c9efc9;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col7 {
#             background-color:  #bfeabf;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col8 {
#             background-color:  #b8e6b8;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col9 {
#             background-color:  #ddfbdd;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col10 {
#             background-color:  #b8e6b8;
#         }    #T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col11 {
#             background-color:  #c7eec7;
#         }</style><table id="T_7110de28_7c9f_11ea_9dda_9b9179a012fe" ><thead>    <tr>        <th class="index_name level0" >arrival_date_month</th>        <th class="col_heading level0 col0" >April</th>        <th class="col_heading level0 col1" >August</th>        <th class="col_heading level0 col2" >December</th>        <th class="col_heading level0 col3" >February</th>        <th class="col_heading level0 col4" >January</th>        <th class="col_heading level0 col5" >July</th>        <th class="col_heading level0 col6" >June</th>        <th class="col_heading level0 col7" >March</th>        <th class="col_heading level0 col8" >May</th>        <th class="col_heading level0 col9" >November</th>        <th class="col_heading level0 col10" >October</th>        <th class="col_heading level0 col11" >September</th>    </tr>    <tr>        <th class="index_name level0" >hotel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7110de28_7c9f_11ea_9dda_9b9179a012felevel0_row0" class="row_heading level0 row0" >City Hotel</th>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col0" class="data row0 col0" >7480</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col1" class="data row0 col1" >8983</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col2" class="data row0 col2" >4132</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col3" class="data row0 col3" >4965</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col4" class="data row0 col4" >3736</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col5" class="data row0 col5" >8088</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col6" class="data row0 col6" >7894</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col7" class="data row0 col7" >6458</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col8" class="data row0 col8" >8232</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col9" class="data row0 col9" >4357</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col10" class="data row0 col10" >7605</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow0_col11" class="data row0 col11" >7400</td>
#             </tr>
#             <tr>
#                         <th id="T_7110de28_7c9f_11ea_9dda_9b9179a012felevel0_row1" class="row_heading level0 row1" >Resort Hotel</th>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col0" class="data row1 col0" >3609</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col1" class="data row1 col1" >4894</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col2" class="data row1 col2" >2648</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col3" class="data row1 col3" >3103</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col4" class="data row1 col4" >2193</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col5" class="data row1 col5" >4573</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col6" class="data row1 col6" >3045</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col7" class="data row1 col7" >3336</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col8" class="data row1 col8" >3559</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col9" class="data row1 col9" >2437</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col10" class="data row1 col10" >3555</td>
#                         <td id="T_7110de28_7c9f_11ea_9dda_9b9179a012ferow1_col11" class="data row1 col11" >3108</td>
#             </tr>
#     </tbody></table>
