# %% [markdown]
# # import

# %%
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd 
from os import path

# %%
import taproc as tp
from taproc.pre_processing import *
from taproc.dataset import *
from taproc.learner import *
from taproc.feature import *

# %% [markdown]
# # read file

# %%
file_path = Path('/media/zero/dropbox/Dropbox/Data science project/kaggle/home_credit_default_risk/data')

# %%
app_train = pd.read_csv(str(file_path/'application_train.csv'))

# %%
app_train_proc, y, na_dict = tabular_proc(app_train, y_fld = 'TARGET', max_n_cat=15)

# %% [raw]
# app_test = pd.read_csv(str(file_path/'application_test.csv'))

# %% [raw]
# app_test_proc, _, _ = tabular_proc(app_test, max_n_cat=15, na_dict = na_dict)

# %% [raw]
# app_train_proc = app_train_proc[app_test_proc.columns]

# %% [markdown]
# # dataset

# %%
dataset = LGBDataset.sklearn_split(app_train_proc, y)

# %% [markdown]
# # keep feature

# %%
keep_ft = flat_list([['EXT_SOURCE_3'],
 ['EXT_SOURCE_2'],
 ['AMT_GOODS_PRICE', 'AMT_CREDIT', 'AMT_ANNUITY'],
 ['EXT_SOURCE_1'],
 ['DAYS_BIRTH'],
 ['DAYS_EMPLOYED'],
 ['CODE_GENDER_M'],
 ['NAME_EDUCATION_TYPE_Higher education'],
 ['EXT_SOURCE_1_na'],
 ['DAYS_ID_PUBLISH'],
 ['NAME_FAMILY_STATUS_Married'],
 ['FLAG_OWN_CAR_N', 'OWN_CAR_AGE'],
 ['CODE_GENDER_F'],
 ['NAME_CONTRACT_TYPE_Cash loans'],
 ['DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE'],
 ['AMT_REQ_CREDIT_BUREAU_HOUR_na',
  'AMT_REQ_CREDIT_BUREAU_DAY_na',
  'AMT_REQ_CREDIT_BUREAU_WEEK_na',
  'AMT_REQ_CREDIT_BUREAU_MON_na',
  'AMT_REQ_CREDIT_BUREAU_QRT_na',
  'AMT_REQ_CREDIT_BUREAU_YEAR_na'],
 ['AMT_REQ_CREDIT_BUREAU_QRT'],
 ['FLAG_DOCUMENT_3'],
 ['AMT_INCOME_TOTAL'],
 ['REGION_POPULATION_RELATIVE'],
 ['NAME_INCOME_TYPE_Working'],
 ['NONLIVINGAPARTMENTS_MODE',
  'NONLIVINGAPARTMENTS_AVG',
  'NONLIVINGAPARTMENTS_MEDI'],
 ['FLAG_WORK_PHONE'],
 ['AMT_REQ_CREDIT_BUREAU_YEAR'],
 ['REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY'],
 ['LIVINGAPARTMENTS_MODE', 'LIVINGAPARTMENTS_AVG', 'LIVINGAPARTMENTS_MEDI'],
 ['FLOORSMIN_AVG', 'FLOORSMIN_MEDI', 'FLOORSMIN_MODE']])

# %%
dataset.filter_column(keep_ft)

# %% [markdown]
# # baseline model

# %%
params = {
    'task': 'train',
    'objective': 'binary',
    'n_estimators':500,
    'learning_rate':0.1,
    'num_leaves':30,
    'colsample_bytree':.8,
    'subsample':.9,
    'max_depth':7,
    'reg_alpha':.1,
    'reg_lambda':.1,
    'min_split_gain':.01,
    'min_child_weight':2,
    'verbose':-1,
    'metric': 'binary_logloss'}

# %%
learner = LGBLearner(dataset)

# %%
learner.load()

# %% [markdown]
# # partial dependence

# %%
pdpd = PartialDependence.from_LGBLearner(learner)

# %%
dataset.lgb_trn.data.head().T
# Out:
#                                         197843     212073     278406  \
# EXT_SOURCE_3                          0.384207  0.0975816   0.652897
# EXT_SOURCE_2                          0.481592   0.341772  0.0760805
# AMT_GOODS_PRICE                         315000     135000     468000
# AMT_CREDIT                              348264     135000     616262
# AMT_ANNUITY                              25470       6750      22266
# EXT_SOURCE_1                          0.504679   0.513312   0.505998
# DAYS_BIRTH                              -13323      -8705     -16768
# DAYS_EMPLOYED                             -495       -402      -1094
# CODE_GENDER_M                                1          0          0
# NAME_EDUCATION_TYPE_Higher education         0          0          0
# EXT_SOURCE_1_na                          False      False       True
# DAYS_ID_PUBLISH                          -3300      -1386       -311
# NAME_FAMILY_STATUS_Married                   1          0          0
# FLAG_OWN_CAR_N                               1          0          1
# OWN_CAR_AGE                                  9          0          9
# CODE_GENDER_F                                0          1          1
# NAME_CONTRACT_TYPE_Cash loans                1          0          1
# DEF_30_CNT_SOCIAL_CIRCLE                     0          1          0
# DEF_60_CNT_SOCIAL_CIRCLE                     0          1          0
# AMT_REQ_CREDIT_BUREAU_HOUR_na            False      False      False
# AMT_REQ_CREDIT_BUREAU_DAY_na             False      False      False
# AMT_REQ_CREDIT_BUREAU_WEEK_na            False      False      False
# AMT_REQ_CREDIT_BUREAU_MON_na             False      False      False
# AMT_REQ_CREDIT_BUREAU_QRT_na             False      False      False
# AMT_REQ_CREDIT_BUREAU_YEAR_na            False      False      False
# AMT_REQ_CREDIT_BUREAU_QRT                    0          0          0
# FLAG_DOCUMENT_3                              1          0          1
# AMT_INCOME_TOTAL                        135000     202500     135000
# REGION_POPULATION_RELATIVE            0.022625   0.010147   0.020246
# NAME_INCOME_TYPE_Working                     1          0          1
# NONLIVINGAPARTMENTS_MODE                     0          0          0
# NONLIVINGAPARTMENTS_AVG                      0          0          0
# NONLIVINGAPARTMENTS_MEDI                     0          0          0
# FLAG_WORK_PHONE                              0          0          0
# AMT_REQ_CREDIT_BUREAU_YEAR                   2          2          2
# REGION_RATING_CLIENT                         2          2          3
# REGION_RATING_CLIENT_W_CITY                  2          2          3
# LIVINGAPARTMENTS_MODE                   0.0771     0.0826     0.0771
# LIVINGAPARTMENTS_AVG                    0.0756     0.0756     0.0756
# LIVINGAPARTMENTS_MEDI                   0.0761      0.077     0.0761
# FLOORSMIN_AVG                           0.2083     0.2083     0.2083
# FLOORSMIN_MEDI                          0.2083     0.2083     0.2083
# FLOORSMIN_MODE                          0.2083     0.2083     0.2083
#
#                                         169832    256338
# EXT_SOURCE_3                           0.42237  0.634706
# EXT_SOURCE_2                           0.56522  0.676409
# AMT_GOODS_PRICE                         225000    675000
# AMT_CREDIT                              254700    781920
# AMT_ANNUITY                            27022.5     34443
# EXT_SOURCE_1                          0.505998  0.505998
# DAYS_BIRTH                              -10420    -21209
# DAYS_EMPLOYED                            -2917    365243
# CODE_GENDER_M                                1         0
# NAME_EDUCATION_TYPE_Higher education         0         0
# EXT_SOURCE_1_na                           True      True
# DAYS_ID_PUBLISH                          -3037     -3951
# NAME_FAMILY_STATUS_Married                   1         0
# FLAG_OWN_CAR_N                               1         1
# OWN_CAR_AGE                                  9         9
# CODE_GENDER_F                                0         1
# NAME_CONTRACT_TYPE_Cash loans                1         1
# DEF_30_CNT_SOCIAL_CIRCLE                     1         0
# DEF_60_CNT_SOCIAL_CIRCLE                     1         0
# AMT_REQ_CREDIT_BUREAU_HOUR_na            False     False
# AMT_REQ_CREDIT_BUREAU_DAY_na             False     False
# AMT_REQ_CREDIT_BUREAU_WEEK_na            False     False
# AMT_REQ_CREDIT_BUREAU_MON_na             False     False
# AMT_REQ_CREDIT_BUREAU_QRT_na             False     False
# AMT_REQ_CREDIT_BUREAU_YEAR_na            False     False
# AMT_REQ_CREDIT_BUREAU_QRT                    0         2
# FLAG_DOCUMENT_3                              1         0
# AMT_INCOME_TOTAL                        112500    112500
# REGION_POPULATION_RELATIVE            0.019689  0.016612
# NAME_INCOME_TYPE_Working                     1         0
# NONLIVINGAPARTMENTS_MODE                     0         0
# NONLIVINGAPARTMENTS_AVG                      0         0
# NONLIVINGAPARTMENTS_MEDI                     0         0
# FLAG_WORK_PHONE                              0         0
# AMT_REQ_CREDIT_BUREAU_YEAR                   2         0
# REGION_RATING_CLIENT                         2         2
# REGION_RATING_CLIENT_W_CITY                  2         2
# LIVINGAPARTMENTS_MODE                   0.0771    0.0771
# LIVINGAPARTMENTS_AVG                    0.0756    0.0706
# LIVINGAPARTMENTS_MEDI                   0.0761    0.0718
# FLOORSMIN_AVG                           0.2083       0.5
# FLOORSMIN_MEDI                          0.2083       0.5
# FLOORSMIN_MODE                          0.2083       0.5

# %%
pdpd.info_target('EXT_SOURCE_3')

# %%
pdpd.info_target('CODE_GENDER_M')

# %%
pdpd.summary['info_target']
# Out:
#    x   display_column  count    target
# 0  0  CODE_GENDER_M_0   6526  0.070794
# 1  1  CODE_GENDER_M_1   3474  0.102188

# %%
pdpd.info_actual('CODE_GENDER_M')

# %%
pdpd.info_actual('EXT_SOURCE_3')

# %%
pdpd.summary['info_actual']
# Out:
#    x display_column  value_lower  value_upper  count  actual_prediction_q1  \
# 0  0    [0.0, 0.28)     0.000527     0.275000   1111              0.090798
# 1  1    [0.28, 0.4)     0.275000     0.396220   1097              0.049714
# 2  2    [0.4, 0.49)     0.396220     0.488455   1123              0.034822
# 3  3   [0.49, 0.54)     0.488455     0.535276    634              0.032607
# 4  4   [0.54, 0.58)     0.535276     0.581484   2690              0.033793
# 5  5   [0.58, 0.65)     0.581484     0.652897   1114              0.021719
# 6  6   [0.65, 0.73)     0.652897     0.725276   1106              0.018687
# 7  7   [0.73, 0.88]     0.725276     0.878740   1125              0.016202
#
#    actual_prediction_q2  actual_prediction_q3
# 0              0.143951              0.227292
# 1              0.083576              0.136016
# 2              0.059996              0.096349
# 3              0.051045              0.082692
# 4              0.058774              0.108268
# 5              0.033087              0.057705
# 6              0.029541              0.047225
# 7              0.024996              0.041187

# %%
pdpd.isolate('EXT_SOURCE_3')

# %%
pdpd.isolate('CODE_GENDER_M')

# %%
pdpd.target_interact(['EXT_SOURCE_3', 'CODE_GENDER_M'])

# %%
pdpd.summary['target_interact']
# Out:
#     x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0    0   0      [0.0, 0.28)  CODE_GENDER_M_0       0.000527       0.275000
# 1    0   1      [0.0, 0.28)  CODE_GENDER_M_1       0.000527       0.275000
# 2    1   0      [0.28, 0.4)  CODE_GENDER_M_0       0.275000       0.396220
# 3    1   1      [0.28, 0.4)  CODE_GENDER_M_1       0.275000       0.396220
# 4    2   0      [0.4, 0.49)  CODE_GENDER_M_0       0.396220       0.488455
# 5    2   1      [0.4, 0.49)  CODE_GENDER_M_1       0.396220       0.488455
# 6    3   0     [0.49, 0.54)  CODE_GENDER_M_0       0.488455       0.535276
# 7    3   1     [0.49, 0.54)  CODE_GENDER_M_1       0.488455       0.535276
# 8    4   0     [0.54, 0.58)  CODE_GENDER_M_0       0.535276       0.584990
# 9    4   1     [0.54, 0.58)  CODE_GENDER_M_1       0.535276       0.584990
# 10   5   0     [0.58, 0.66)  CODE_GENDER_M_0       0.584990       0.656158
# 11   5   1     [0.58, 0.66)  CODE_GENDER_M_1       0.584990       0.656158
# 12   6   0     [0.66, 0.73)  CODE_GENDER_M_0       0.656158       0.729567
# 13   6   1     [0.66, 0.73)  CODE_GENDER_M_1       0.656158       0.729567
# 14   7   0     [0.73, 0.89]  CODE_GENDER_M_0       0.729567       0.893976
# 15   7   1     [0.73, 0.89]  CODE_GENDER_M_1       0.729567       0.893976
#
#     count    target
# 0     723  0.167358
# 1     386  0.243523
# 2     705  0.090780
# 3     401  0.114713
# 4     733  0.060027
# 5     383  0.104439
# 6     409  0.058680
# 7     218  0.087156
# 8    1762  0.073212
# 9     944  0.098517
# 10    762  0.049869
# 11    337  0.062315
# 12    724  0.029006
# 13    384  0.059896
# 14    765  0.022222
# 15    364  0.054945

# %%
pdpd.actual_interact(['EXT_SOURCE_3', 'CODE_GENDER_M'])

# %%
pdpd.summary['actual_interact']
# Out:
#     x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0    0   0      [0.0, 0.27)  CODE_GENDER_M_0       0.000527       0.272134
# 1    0   1      [0.0, 0.27)  CODE_GENDER_M_1       0.000527       0.272134
# 2    1   0     [0.27, 0.39)  CODE_GENDER_M_0       0.272134       0.392774
# 3    1   1     [0.27, 0.39)  CODE_GENDER_M_1       0.272134       0.392774
# 4    2   0     [0.39, 0.49)  CODE_GENDER_M_0       0.392774       0.486653
# 5    2   1     [0.39, 0.49)  CODE_GENDER_M_1       0.392774       0.486653
# 6    3   0     [0.49, 0.54)  CODE_GENDER_M_0       0.486653       0.535276
# 7    3   1     [0.49, 0.54)  CODE_GENDER_M_1       0.486653       0.535276
# 8    4   0     [0.54, 0.59)  CODE_GENDER_M_0       0.535276       0.586740
# 9    4   1     [0.54, 0.59)  CODE_GENDER_M_1       0.535276       0.586740
# 10   5   0     [0.59, 0.66)  CODE_GENDER_M_0       0.586740       0.656158
# 11   5   1     [0.59, 0.66)  CODE_GENDER_M_1       0.586740       0.656158
# 12   6   0     [0.66, 0.73)  CODE_GENDER_M_0       0.656158       0.728141
# 13   6   1     [0.66, 0.73)  CODE_GENDER_M_1       0.656158       0.728141
# 14   7   0     [0.73, 0.88]  CODE_GENDER_M_0       0.728141       0.882530
# 15   7   1     [0.73, 0.88]  CODE_GENDER_M_1       0.728141       0.882530
#
#     count  actual_prediction_q1  actual_prediction_q2  actual_prediction_q3
# 0     713              0.088560              0.139242              0.215076
# 1     384              0.108212              0.179250              0.294187
# 2     722              0.048072              0.075492              0.123242
# 3     400              0.060495              0.099462              0.161572
# 4     751              0.034098              0.055534              0.088181
# 5     352              0.047070              0.073864              0.121216
# 6     408              0.028228              0.045344              0.067661
# 7     221              0.039203              0.070804              0.116442
# 8    1773              0.031531              0.051318              0.084513
# 9     925              0.041322              0.075489              0.137384
# 10    805              0.020473              0.032487              0.048340
# 11    308              0.023636              0.041719              0.069992
# 12    774              0.017653              0.026851              0.042126
# 13    334              0.021123              0.035632              0.060468
# 14    778              0.014706              0.021869              0.034213
# 15    352              0.018977              0.031522              0.048760

# %%
pdpd.pdp_interact(['EXT_SOURCE_3', 'CODE_GENDER_M'])
